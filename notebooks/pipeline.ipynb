# %%
import numpy as np
import pandas as pd
#pd.set_option('display.max_rows', 1500)
pd.set_option('display.max_columns', 100)

# %%
import urllib.request, json 
with urllib.request.urlopen("http://galvanize-case-study-on-fraud.herokuapp.com/data_point") as url:
    data = json.loads(url.read().decode())
    

#data

# %%
# Out:
#   approx_payout_date body_length channels country currency delivery_method  \
# 0         1353619800           0        5      CA      CAD               0
#
#   description email_domain event_created   event_end event_published  \
# 0                gmail.com    1349953698  1353187800     1.34995e+09
#
#   event_start fb_published      gts has_analytics has_header has_logo listed  \
# 0  1353177000            0  1641.02             0          0        1      y
#
#                 name name_length num_order num_payouts object_id org_desc  \
# 0  MJ Durkin Toronto          17        81           1   4259762
#
#   org_facebook                                org_name org_twitter payee_name  \
# 0            0  Kelly McAllister Arbonne International           0
#
#   payout_type                                   previous_payouts  \
# 0         ACH  [{'address': '', 'amount': 2600.0, 'country': ...
#
#   sale_duration sale_duration2 show_map  \
# 0            37             37        1
#
# ...

# %%
data_g.to_csv('../data/pipeline_example.csv')

# %%
test = pd.read_csv('../data/pipeline_example.csv')

# %%
test
# Out:
#    Unnamed: 0  approx_payout_date  body_length  channels country currency  \
# 0           0          1353619800            0         5      CA      CAD
#
#    delivery_method  description email_domain  event_created   event_end  \
# 0              0.0          NaN    gmail.com     1349953698  1353187800
#
#    event_published  event_start  fb_published      gts  has_analytics  \
# 0     1.349954e+09   1353177000             0  1641.02              0
#
#    has_header  has_logo listed               name  name_length  num_order  \
# 0         0.0         1      y  MJ Durkin Toronto           17         81
#
#    num_payouts  object_id  org_desc  org_facebook  \
# 0            1    4259762       NaN           0.0
#
#                                  org_name  org_twitter  payee_name  \
# 0  Kelly McAllister Arbonne International          0.0         NaN
#
#   payout_type                                   previous_payouts  \
# ...

# %%
import json, requests

r = requests.get(url = "http://galvanize-case-study-on-fraud.herokuapp.com/data_point") 
json_data = json.loads(r.text)
json_data
# Out:
# {'approx_payout_date': 1341169200,
#  'body_length': 502,
#  'channels': 8,
#  'country': None,
#  'currency': 'USD',
#  'delivery_method': 1.0,
#  'description': '<p>Kids will learn skills in three different sports or cheer, while having fun, enjoying snacks and short devotions, and making new friends. All skill levels welcome. For children entering K-5th grade in Fall 2012.</p>\r\n<h3>Schedule</h3>\r\n<p style="padding-left: 30px;"><strong>Tuesdays, June 12, 19 and 26</strong><br /> <strong>9am-12pm</strong></p>\r\n<h3>Registration</h3>\r\n<p style="padding-left: 30px;"><strong>$20/child</strong><br /> <strong>Includes t-shirt and take-home devotional</strong></p>',
#  'email_domain': 'crossroadscolorado.com',
#  'event_created': 1337283301,
#  'event_end': 1340737200,
#  'event_published': 1337284374.0,
#  'event_start': 1339516800,
#  'fb_published': 0,
#  'gts': 660.0,
#  'has_analytics': 0,
#  'has_header': None,
#  'has_logo': 0,
#  'listed': 'y',
# ...

# %%
#data_pd= pd.read_json(data)
#data_pd = pd.from_dict(data)
data2 = pd.DataFrame.from_dict(json_data, orient='index')
data2= data2.T
data2
# Out:
#   approx_payout_date body_length channels country currency delivery_method  \
# 0         1341169200         502        8    None      USD               1
#
#                                          description            email_domain  \
# 0  <p>Kids will learn skills in three different s...  crossroadscolorado.com
#
#   event_created   event_end event_published event_start fb_published  gts  \
# 0    1337283301  1340737200     1.33728e+09  1339516800            0  660
#
#   has_analytics has_header has_logo listed                   name name_length  \
# 0             0       None        0      y  Sports & Cheer Clinic          21
#
#   num_order num_payouts object_id org_desc org_facebook           org_name  \
# 0        22           4   3567857                    18  Crossroads Church
#
#   org_twitter         payee_name payout_type  \
# 0          15  Crossroads Church       CHECK
#
#                                     previous_payouts sale_duration  \
# ...
